# %% [markdown]
# # CNN para Detección de Enfermedades Orales
# ### Dataset: [Oral Diseases – Kaggle](https://www.kaggle.com/datasets/salmansajid05/oral-diseases)
# Algoritmos bioinspirados aplicados a clasificación de imágenes médicas.

# %% [markdown]
# ## Imports

# %%
import sys
sys.path.append('C:/Users/allan/OneDrive/Documentos/GitHub/BioInspirado/Bioalgoritmo')

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.applications import EfficientNetB0

from sklearn.metrics import classification_report, confusion_matrix

from ManejoDeDatos.data_loader import load_dataset_bd

print("TensorFlow version:", tf.__version__)
print("GPU disponible:", tf.config.list_physical_devices('GPU'))

# %% [markdown]
# ## 1. Cargar datos desde PostgreSQL

# %%
train_ds, val_ds, class_names = load_dataset_bd(use_augmentation=True)

NUM_CLASSES = len(class_names)
print("Clases:", class_names)
